# %%
import pandas as pd
import numpy as np
import os

import src.results.binary_prediction_utils as bin_utils

# %%
os.chdir("../..")

# %%
# Get labels
y_true = pd.read_csv("../../results/MIMIC/XGBALL/run6/y_true.csv", index_col=0, header=0)
y_pred = pd.read_csv("../../results/MIMIC/XGBALL/run6/y_pred.csv", index_col=0, header=0)

# %%
# Plot AUROC
bin_utils.plot_auc_auprc(y_true.values, y_pred.values, outc_names=["De", "I", "W", "Di"], num=100)
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  array([<AxesSubplot:title={'center':'ROC Curve'}, xlabel='FPR', ylabel='TPR'>,
#         <AxesSubplot:title={'center':'PRC Curve'}, xlabel='Recall', ylabel='Precision'>],
#        dtype=object))

# %%
# Plot AUROC
bin_utils.plot_auc_auprc(y_true.values, y_pred.values, outc_names=["De", "I", "W", "Di"], num=10)
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  array([<AxesSubplot:title={'center':'ROC Curve'}, xlabel='FPR', ylabel='TPR'>,
#         <AxesSubplot:title={'center':'PRC Curve'}, xlabel='Recall', ylabel='Precision'>],
#        dtype=object))
